# %%
import matplotlib.pyplot as plt 
from env import simulator

# %%
N = 10000
T = 200
match_prob = [[0.8, 0.1], [0.8, 0.1]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r,= simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

# %%
r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
# r_e_ = [i/N for i in r_e]
p_s_ = [i/N for i in partial_s]
# p_e_ = [i/N for i in partial_e]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
# plt.plot([i for i in range(T)], r_e_, label='epsilon-greedy')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')
# plt.plot([i for i in range(T)], p_e_, label='partial_info_e_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.title('[0.8, 0.1], [0.8, 0.1]')
plt.legend()
plt.show()

# %%
N = 10000
T = 200
match_prob = [[0.1, 0.8], [0.8, 0.1]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r, = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r, = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

# %%
r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
# r_e_ = [i/N for i in r_e]
p_s_ = [i/N for i in partial_s]
# p_e_ = [i/N for i in partial_e]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
# plt.plot([i for i in range(T)], r_e_, label='epsilon-greedy')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')
# plt.plot([i for i in range(T)], p_e_, label='partial_info_e_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.title('[0.1, 0.8], [0.8, 0.1]')
plt.legend()
plt.show()

# %%
N = 10000
T = 200
match_prob = [[1, 1], [1, 0]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

# %%
r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
p_s_ = [i/N for i in partial_s]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.legend()
plt.title('[1, 1], [1, 0]')
plt.show()

# %%
N = 10000
T = 200
match_prob = [[0.5, 0.25], [0.25, 0.5]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

# %%
r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
p_s_ = [i/N for i in partial_s]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.legend()
plt.title('[0.5, 0.25], [0.25, 0.5]')
plt.show()

# %%
from strategies import *

# %%
for i in range(5):
    print(random_date(5))
# Out:
# [(0, 9), (1, 6), (2, 8), (4, 7), (3, 5)]
# [(3, 5), (4, 7), (2, 8), (0, 9), (1, 6)]
# [(2, 8), (4, 6), (0, 5), (1, 7), (3, 9)]
# [(0, 7), (2, 6), (3, 5), (4, 9), (1, 8)]
# [(3, 9), (1, 6), (2, 7), (4, 8), (0, 5)]

# %%
N = 10000
T = 200
match_prob = [[0.8, 0.8], [0.8, 0.3]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
p_s_ = [i/N for i in partial_s]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.legend()
plt.title('[0.8, 0.8], [0.8, 0.3]')
plt.show()

# %%
N = 10000
T = 200
match_prob = [[0.1, 0.1], [0.1, 0.3]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
p_s_ = [i/N for i in partial_s]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.legend()
plt.title('[0.1, 0.1], [0.1, 0.3]')
plt.show()

# %%
N = 10000
T = 200
match_prob = [[0.1, 0.2], [0.1, 0.3]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
p_s_ = [i/N for i in partial_s]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.legend()
plt.title(f'{match_prob}')
plt.show()

# %%
N = 10000
T = 200
match_prob = [[0.8, 0.3], [0.1, 0.1]]
ratio1 = 0.5
ratio2 = 0.5
initial_guess = [0.5, 0.5]
r_s, r_o, r_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess)

partial_s, partial_o, partial_r = simulator(N, T, match_prob, ratio1, ratio2, initial_guess, full_info=False)

r_s_ = [i/N for i in r_s]
r_o_ = [i/N for i in r_o]
r_r_ = [i/N for i in r_r]
p_s_ = [i/N for i in partial_s]
plt.plot([i for i in range(T)], r_s_, label='greedy')
plt.plot([i for i in range(T)], r_o_, label='offline')
plt.plot([i for i in range(T)], r_r_, label='random')
plt.plot([i for i in range(T)], p_s_, label='partial_info_greedy')

plt.xlabel('Iteration')
plt.ylabel('match rate')
plt.legend()
plt.title(f'{match_prob}')
plt.show()
